# %%
import ipywidgets as widgets
from IPython.display import display
import requests

class TableManagementDashboard:
    def __init__(self, user, host, output):
        self.user = user
        self.host = host
        self.out = output
        self.create_login = widgets.Button(
            description='Create Login',
            disabled=False,
            button_style='success', # 'success', 'info', 'warning', 'danger' or ''
            tooltip='Create Room',
            icon='check' # (FontAwesome names without the `fa-` prefix) 
        )
        self.create_employee = widgets.Button(
            description='Create Employee',
            disabled=False,
            button_style='success', # 'success', 'info', 'warning', 'danger' or ''
            tooltip='Create Employee',
            icon='check' # (FontAwesome names without the `fa-` prefix) 
        )
        self.create_chains = widgets.Button(
            description='Create Chains',
            disabled=False,
            button_style='success', # 'success', 'info', 'warning', 'danger' or ''
            tooltip='Create Chains',
            icon='check' # (FontAwesome names without the `fa-` prefix) 
        )
        self.create_hotel = widgets.Button(
            description='Create Hotel',
            disabled=False,
            button_style='success', # 'success', 'info', 'warning', 'danger' or ''
            tooltip='Create Hotel',
            icon='check' # (FontAwesome names without the `fa-` prefix) 
        )
        self.create_roomdescription = widgets.Button(
            description='Create Room Description',
            disabled=False,
            button_style='success', # 'success', 'info', 'warning', 'danger' or ''
            tooltip='Create Room Description',
            icon='check' # (FontAwesome names without the `fa-` prefix) 
        )
        self.create_client = widgets.Button(
            description='Create Client',
            disabled=False,
            button_style='success', # 'success', 'info', 'warning', 'danger' or ''
            tooltip='Create Client',
            icon='check' # (FontAwesome names without the `fa-` prefix) 
        )
        self.create_reserve = widgets.Button(
            description='Create Reserve',
            disabled=False,
            button_style='success', # 'success', 'info', 'warning', 'danger' or ''
            tooltip='Create Reserve',
            icon='check' # (FontAwesome names without the `fa-` prefix) 
        )
        self.create_roomunavailable = widgets.Button(
            description='Create Room Unavailable',
            disabled=False,
            button_style='success', # 'success', 'info', 'warning', 'danger' or ''
            tooltip='Create Room Unavailable',
            icon='check' # (FontAwesome names without the `fa-` prefix) 
        )
        self.create_room = widgets.Button(
            description='Create Room',
            disabled=False,
            button_style='success', # 'success', 'info', 'warning', 'danger' or ''
            tooltip='Create Room',
            icon='check' # (FontAwesome names without the `fa-` prefix) 
        )
        self.update_login = widgets.Button(
            description='Update Login',
            disabled=False,
            button_style='success', # 'success', 'info', 'warning', 'danger' or ''
            tooltip='Update Login',
            icon='check' # (FontAwesome names without the `fa-` prefix) 
        )
        self.update_employee = widgets.Button(
            description='Update Employee',
            disabled=False,
            button_style='success', # 'success', 'info', 'warning', 'danger' or ''
            tooltip='Update Employee',
            icon='check' # (FontAwesome names without the `fa-` prefix) 
        )
        self.update_chains = widgets.Button(
            description='Update Chains',
            disabled=False,
            button_style='success', # 'success', 'info', 'warning', 'danger' or ''
            tooltip='Update Chains',
            icon='check' # (FontAwesome names without the `fa-` prefix) 
        )
        self.update_hotel = widgets.Button(
            description='Update Hotel',
            disabled=False,
            button_style='success', # 'success', 'info', 'warning', 'danger' or ''
            tooltip='Update Hotel',
            icon='check' # (FontAwesome names without the `fa-` prefix) 
        )
        self.update_roomdescription = widgets.Button(
            description='Update Room Description',
            disabled=False,
            button_style='success', # 'success', 'info', 'warning', 'danger' or ''
            tooltip='Update Room Description',
            icon='check' # (FontAwesome names without the `fa-` prefix) 
        )
        self.update_client = widgets.Button(
            description='Update Client',
            disabled=False,
            button_style='success', # 'success', 'info', 'warning', 'danger' or ''
            tooltip='Update Client',
            icon='check' # (FontAwesome names without the `fa-` prefix) 
        )
        self.update_reserve = widgets.Button(
            description='Update Reserve',
            disabled=False,
            button_style='success', # 'success', 'info', 'warning', 'danger' or ''
            tooltip='Update Reserve',
            icon='check' # (FontAwesome names without the `fa-` prefix) 
        )
        self.update_roomunavailable = widgets.Button(
            description='Update Room Unavailable',
            disabled=False,
            button_style='success', # 'success', 'info', 'warning', 'danger' or ''
            tooltip='Update Room Unavailable',
            icon='check' # (FontAwesome names without the `fa-` prefix) 
        )
        self.update_room = widgets.Button(
            description='Update Room',
            disabled=False,
            button_style='success', # 'success', 'info', 'warning', 'danger' or ''
            tooltip='Update Room',
            icon='check' # (FontAwesome names without the `fa-` prefix) 
        )
        self.delete_login = widgets.Button(
            description='Delete Login',
            disabled=False,
            button_style='success', # 'success', 'info', 'warning', 'danger' or ''
            tooltip='Delete Login',
            icon='check' # (FontAwesome names without the `fa-` prefix) 
        )
        self.delete_employee = widgets.Button(
            description='Delete Employee',
            disabled=False,
            button_style='success', # 'success', 'info', 'warning', 'danger' or ''
            tooltip='Delete Employee',
            icon='check' # (FontAwesome names without the `fa-` prefix) 
        )
        self.delete_chains = widgets.Button(
            description='Delete Chains',
            disabled=False,
            button_style='success', # 'success', 'info', 'warning', 'danger' or ''
            tooltip='Delete Chains',
            icon='check' # (FontAwesome names without the `fa-` prefix) 
        )
        self.delete_hotel = widgets.Button(
            description='Delete Hotel',
            disabled=False,
            button_style='success', # 'success', 'info', 'warning', 'danger' or ''
            tooltip='Delete Hotel',
            icon='check' # (FontAwesome names without the `fa-` prefix) 
        )
        self.delete_roomdescription = widgets.Button(
            description='Delete Room Description',
            disabled=False,
            button_style='success', # 'success', 'info', 'warning', 'danger' or ''
            tooltip='Delete Room Description',
            icon='check' # (FontAwesome names without the `fa-` prefix) 
        )
        self.delete_client = widgets.Button(
            description='Delete Client',
            disabled=False,
            button_style='success', # 'success', 'info', 'warning', 'danger' or ''
            tooltip='Delete Client',
            icon='check' # (FontAwesome names without the `fa-` prefix) 
        )
        self.delete_reserve = widgets.Button(
            description='Delete Reserve',
            disabled=False,
            button_style='success', # 'success', 'info', 'warning', 'danger' or ''
            tooltip='Delete Reserve',
            icon='check' # (FontAwesome names without the `fa-` prefix) 
        )
        self.delete_roomunavailable = widgets.Button(
            description='Delete Room Unavailable',
            disabled=False,
            button_style='success', # 'success', 'info', 'warning', 'danger' or ''
            tooltip='Delete Room Unavailable',
            icon='check' # (FontAwesome names without the `fa-` prefix) 
        )
        self.delete_room = widgets.Button(
            description='Delete Room',
            disabled=False,
            button_style='success', # 'success', 'info', 'warning', 'danger' or ''
            tooltip='Delete Room',
            icon='check' # (FontAwesome names without the `fa-` prefix) 
        )

        self.create_login.on_click(lambda x: self.launch_login('Create'))
        self.update_login.on_click(lambda x: self.launch_login('Update'))
        self.delete_login.on_click(lambda x: self.launch_login('Delete'))
        self.create_employee.on_click(lambda x: self.launch_employee('Create'))
        self.update_employee.on_click(lambda x: self.launch_employee('Update'))
        self.delete_employee.on_click(lambda x: self.launch_employee('Delete'))
        self.create_chains.on_click(lambda x: self.launch_chains('Create'))
        self.update_chains.on_click(lambda x: self.launch_chains('Update'))
        self.delete_chains.on_click(lambda x: self.launch_chains('Delete'))
        self.create_hotel.on_click(lambda x: self.launch_hotel('Create'))
        self.update_hotel.on_click(lambda x: self.launch_hotel('Update'))
        self.delete_hotel.on_click(lambda x: self.launch_hotel('Delete'))
        self.create_roomdescription.on_click(lambda x: self.launch_roomdescription('Create'))
        self.update_roomdescription.on_click(lambda x: self.launch_roomdescription('Update'))
        self.delete_roomdescription.on_click(lambda x: self.launch_roomdescription('Delete'))
        self.create_client.on_click(lambda x: self.launch_client('Create'))
        self.update_client.on_click(lambda x: self.launch_client('Update'))
        self.delete_client.on_click(lambda x: self.launch_client('Delete'))
        self.create_reserve.on_click(lambda x: self.launch_reserve('Create'))
        self.update_reserve.on_click(lambda x: self.launch_reserve('Update'))
        self.delete_reserve.on_click(lambda x: self.launch_reserve('Delete'))
        self.create_roomunavailable.on_click(lambda x: self.launch_roomunavailable('Create'))
        self.update_roomunavailable.on_click(lambda x: self.launch_roomunavailable('Update'))
        self.delete_roomunavailable.on_click(lambda x: self.launch_roomunavailable('Delete'))
        self.create_room.on_click(lambda x: self.launch_room('Create'))
        self.update_room.on_click(lambda x: self.launch_room('Update'))
        self.delete_room.on_click(lambda x: self.launch_room('Delete'))
        
        
    def launch_employee(self, purpose):
        self.hideTableManagementDashboard()
        with self.out:
            # %run Employee.ipynb
            run(self.user, self.host, self.out, purpose)

    def launch_room(self, purpose):
       self.hideTableManagementDashboard()
       with self.out:
           # %run Room.ipynb
           run(self.user, self.host, self.out, purpose)

    def launch_roomDescription(self, purpose):
        self.hideTableManagementDashboard()
        with self.out:
            # %run RoomDescription.ipynb
            run(self.user, self.host, self.out, purpose)

    def launch_reserve(self, purpose):
        self.hideTableManagementDashboard()
        with self.out:
            # %run Reserve.ipynb
            run(self.user, self.host, self.out, purpose)
            
    def launch_login(self, purpose):
        self.hideTableManagementDashboard()
        with self.out:
            # %run Login.ipynb
            run(self.user, self.host, self.out, purpose)

    def launch_reserve(self, purpose):
        self.hideTableManagementDashboard()
        with self.out:
            # %run Reserve.ipynb
            run(self.user, self.host, self.out, purpose)
                        
    def launch_chains(self, purpose):
        self.hideTableManagementDashboard()
        with self.out:
            # %run Chains.ipynb
            run(self.user, self.host, self.out, purpose)

    def launch_employee(self, purpose):
        self.hideTableManagementDashboard()
        with self.out:
            # %run Employee.ipynb
            run(self.user, self.host, self.out, purpose)

    def launch_hotel(self, purpose):
        self.hideTableManagementDashboard()
        with self.out:
            # %run Hotels.ipynb
            run(self.user, self.host, self.out, purpose)
            
    def launch_roomdescription(self, purpose):
        self.hideTableManagementDashboard()
        with self.out:
            # %run RoomDescription.ipynb
            run(self.user, self.host, self.out, purpose)
            
    def launch_client(self, purpose):
        self.hideTableManagementDashboard()
        with self.out:
            # %run Client.ipynb
            run(self.user, self.host, self.out, purpose)
            
    def launch_roomunavailable(self, purpose):
        self.hideTableManagementDashboard()
        with self.out:
            # %run RoomUnavailable.ipynb
            run(self.user, self.host, self.out, purpose)
        
    
    def create_update_collumn(self):
        return widgets.VBox(
            [
                self.update_login,
                self.update_employee,
                self.update_chains,
                self.update_hotel,
                self.update_roomdescription,
                self.update_client,
                self.update_reserve,
                self.update_roomunavailable,
                self.update_room
            ]
        )
    def create_create_collumn(self):
        return widgets.VBox(
            [
                self.create_login,
                self.create_employee,
                self.create_chains,
                self.create_hotel,
                self.create_roomdescription,
                self.create_client,
                self.create_reserve,
                self.create_roomunavailable,
                self.create_room
            ]
        )
        
    def create_delete_collumn(self):
        return widgets.VBox(
            [
                self.delete_login,
                self.delete_employee,
                self.delete_chains,
                self.delete_hotel,
                self.delete_roomdescription,
                self.delete_client,
                self.delete_reserve,
                self.delete_roomunavailable,
                self.delete_room
            ]
        )
    def displayTableManagementDashboard(self):
        with self.out:
            if self.user['position'] == 'Administrator':
                display(widgets.HBox([self.create_create_collumn(), self.create_update_collumn(), self.create_delete_collumn()]))
            elif self.user['position'] == 'Supervisor':
                display(widgets.HBox([self.create_roomunavailable, self.create_reserve]))
            else:
                display(self.create_reserve)

    def hideTableManagementDashboard(self):
        self.update_login.close()
        self.update_employee.close()
        self.update_chains.close()
        self.update_hotel.close()
        self.update_roomdescription.close()
        self.update_client.close()
        self.update_reserve.close()
        self.update_roomunavailable.close()
        self.update_room.close()
        self.delete_login.close()
        self.delete_employee.close()
        self.delete_chains.close()
        self.delete_hotel.close()
        self.delete_roomdescription.close()
        self.delete_client.close()
        self.delete_reserve.close()
        self.delete_roomunavailable.close()
        self.delete_room.close()
        self.create_login.close()
        self.create_employee.close()
        self.create_chains.close()
        self.create_hotel.close()
        self.create_roomdescription.close()
        self.create_client.close()
        self.create_reserve.close()
        self.create_roomunavailable.close()
        self.create_room.close()

def run(user, host, output):
    x = TableManagementDashboard(user, host, output)
    with x.out:
        x.displayTableManagementDashboard()
