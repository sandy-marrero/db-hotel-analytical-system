# %%
import ipywidgets as widgets
from IPython.display import display
import requests
from natsort import natsorted

class GlobalAggregatesDashboard:
    def __init__(self, user, host, output):
        self.user = user
        self.host = host
        self.out = output
        self.most_revenue = widgets.Button(
            description='View Most Revenue Aggregate',
            disabled=False,
            button_style='success', # 'success', 'info', 'warning', 'danger' or ''
            tooltip='Click here to view Handicap Room Aggregate',
            icon='check', # (FontAwesome names without the `fa-` prefix)
            layout=widgets.Layout(width='40%')
        )
        self.paymentmethod = widgets.Button(
            description='View Payment Method Aggregate',
            disabled=False,
            button_style='success', # 'success', 'info', 'warning', 'danger' or ''
            tooltip='Click here to view Handicap Room Aggregate',
            icon='check', # (FontAwesome names without the `fa-` prefix)
            layout=widgets.Layout(width='40%')
        )
        self.least_rooms = widgets.Button(
            description='View Least Rooms Aggregate',
            disabled=False,
            button_style='success', # 'success', 'info', 'warning', 'danger' or ''
            tooltip='Click here to view Handicap Room Aggregate',
            icon='check', # (FontAwesome names without the `fa-` prefix)
            layout=widgets.Layout(width='40%')
        )
        self.most_capacity = widgets.Button(
            description='View Most Capacity Aggregate',
            disabled=False,
            button_style='success', # 'success', 'info', 'warning', 'danger' or ''
            tooltip='Click here to view Most Capacity Aggregate',
            icon='check', # (FontAwesome names without the `fa-` prefix)
            layout=widgets.Layout(width='40%')
        )
        self.most_reservation = widgets.Button(
            description='View Most Reservation Aggregate',
            disabled=False,
            button_style='success', # 'success', 'info', 'warning', 'danger' or ''
            tooltip='Click here to view Most Reservation Aggregate',
            icon='check', # (FontAwesome names without the `fa-` prefix)
            layout=widgets.Layout(width='40%')
        )
        self.most_profit_month = widgets.Button(
            description='View Most Profit Month Aggregate',
            disabled=False,
            button_style='success', # 'success', 'info', 'warning', 'danger' or ''
            tooltip='Click here to view Most Profit Month Aggregate',
            icon='check', # (FontAwesome names without the `fa-` prefix)
            layout=widgets.Layout(width='40%')
        )

        self.most_revenue.on_click(self.launch_most_revenue)
        self.paymentmethod.on_click(self.launch_paymentmethod)
        self.least_rooms.on_click(self.launch_least_rooms)
        self.most_capacity.on_click(self.launch_most_capacity)
        self.most_reservation.on_click(self.launch_most_reservation)
        self.most_profit_month.on_click(self.launch_profit_month)

    def displayGlobalAggregatesDashboard(self):
        display(self.most_revenue)
        display(self.paymentmethod)
        display(self.least_rooms)
        display(self.most_capacity)
        display(self.most_reservation)
        display(self.most_profit_month)
        
    
    def launch_most_revenue(self,b):
        with self.out:
            self.hideGlobalAggregatesDashboard()
            # %run Global_Aggregates/MostRevenue.ipynb
            run(self.user, self.host, self.out)
    
    def launch_paymentmethod(self,b):
        with self.out:
            self.hideGlobalAggregatesDashboard()
            # %run Global_Aggregates/PaymentMethod.ipynb
            run(self.user, self.host, self.out)
    
    def launch_least_rooms(self,b):
        with self.out:
            self.hideGlobalAggregatesDashboard()
            # %run Global_Aggregates/LeastRooms.ipynb
            run(self.user, self.host, self.out)

    def launch_most_capacity(self,b):
        with self.out:
            self.hideGlobalAggregatesDashboard()
            # %run Global_Aggregates/MostCapacity.ipynb
            run(self.user, self.host, self.out)
    
    def launch_most_reservation(self,b):
        with self.out:
            self.hideGlobalAggregatesDashboard()
            # %run Global_Aggregates/MostReservation.ipynb
            run(self.user, self.host, self.out)

    
    def launch_profit_month(self,b):
        with self.out:
            self.hideGlobalAggregatesDashboard()
            # %run Global_Aggregates/MostProfitMonth.ipynb
            run(self.user, self.host, self.out)

    def hideGlobalAggregatesDashboard(self):
        self.most_revenue.close()
        self.paymentmethod.close()
        self.least_rooms.close()
        self.most_capacity.close()
        self.most_reservation.close()
        self.most_profit_month.close()

def run(user, host, output):
    x = GlobalAggregatesDashboard(user, host, output)
    x.displayGlobalAggregatesDashboard()
