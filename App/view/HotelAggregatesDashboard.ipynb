# %%
import ipywidgets as widgets
from IPython.display import display
import requests
from natsort import natsorted

class HotelAggregatesDashboard:
    def __init__(self, user, host, output):
        self.user = user
        self.host = host
        self.out = output
        self.handicaproom = widgets.Button(
            description='View Handicap Room Aggregate',
            disabled=False,
            button_style='success', # 'success', 'info', 'warning', 'danger' or ''
            tooltip='Click here to view Handicap Room Aggregate',
            icon='check', # (FontAwesome names without the `fa-` prefix)
            layout=widgets.Layout(width='40%')
        )
        self.leastreserve = widgets.Button(
            description='View Least Reserve Aggregate',
            disabled=False,
            button_style='success', # 'success', 'info', 'warning', 'danger' or ''
            tooltip='Click here to view Handicap Room Aggregate',
            icon='check', # (FontAwesome names without the `fa-` prefix)
            layout=widgets.Layout(width='40%')
        )
        self.mostcreditcard = widgets.Button(
            description='View Most Credit Card Aggregate',
            disabled=False,
            button_style='success', # 'success', 'info', 'warning', 'danger' or ''
            tooltip='Click here to view Handicap Room Aggregate',
            icon='check', # (FontAwesome names without the `fa-` prefix)
            layout=widgets.Layout(width='40%')
        )
        self.highestpaid = widgets.Button(
            description='View Highest Paid Aggregate',
            disabled=False,
            button_style='success', # 'success', 'info', 'warning', 'danger' or ''
            tooltip='Click here to view Handicap Room Aggregate',
            icon='check', # (FontAwesome names without the `fa-` prefix)
            layout=widgets.Layout(width='40%')
        )
        self.mostdiscount = widgets.Button(
            description='View Most Discount Aggregate',
            disabled=False,
            button_style='success', # 'success', 'info', 'warning', 'danger' or ''
            tooltip='Click here to view Handicap Room Aggregate',
            icon='check', # (FontAwesome names without the `fa-` prefix)
            layout=widgets.Layout(width='40%')
        )
        self.roomtype = widgets.Button(
            description='View Room Type Aggregate',
            disabled=False,
            button_style='success', # 'success', 'info', 'warning', 'danger' or ''
            tooltip='Click here to view Handicap Room Aggregate',
            icon='check', # (FontAwesome names without the `fa-` prefix)
            layout=widgets.Layout(width='40%')
        )
        self.leastguests = widgets.Button(
            description='View Least Guests Aggregate',
            disabled=False,
            button_style='success', # 'success', 'info', 'warning', 'danger' or ''
            tooltip='Click here to view Handicap Room Aggregate',
            icon='check', # (FontAwesome names without the `fa-` prefix)
            layout=widgets.Layout(width='40%')
        )

        self.handicaproom.on_click(self.launch_handicaproom)
        self.leastreserve.on_click(self.launch_leastreserve)
        self.mostcreditcard.on_click(self.launch_mostcreditcard)
        self.highestpaid.on_click(self.launch_highestpaid)
        self.mostdiscount.on_click(self.launch_mostdiscount)
        self.roomtype.on_click(self.launch_roomtype)
        self.leastguests.on_click(self.launch_leastguests)

    def displayHotelAggregatesDashboard(self):
        display(self.handicaproom)
        display(self.leastreserve)
        display(self.mostcreditcard)
        display(self.highestpaid)
        display(self.mostdiscount)
        display(self.roomtype)
        display(self.leastguests)
        
    
    def launch_handicaproom(self,b):
        with self.out:
            self.hideHotelAggregatesDashboard()
            # %run Local_Aggregates/HandicapRoom.ipynb
            run(self.user, self.host, self.out)
    
    def launch_leastreserve(self,b):
        with self.out:
            self.hideHotelAggregatesDashboard()
            # %run Local_Aggregates/LeastReserve.ipynb
            run(self.user, self.host, self.out)
    
    def launch_mostcreditcard(self,b):
        with self.out:
            self.hideHotelAggregatesDashboard()
            # %run Local_Aggregates/MostCreditCard.ipynb
            run(self.user, self.host, self.out)

    def launch_highestpaid(self,b):
        with self.out:
            self.hideHotelAggregatesDashboard()
            # %run Local_Aggregates/HighestPaid.ipynb
            run(self.user, self.host, self.out)
    
    def launch_mostdiscount(self,b):
        with self.out:
            self.hideHotelAggregatesDashboard()
            # %run Local_Aggregates/MostDiscount.ipynb
            run(self.user, self.host, self.out)

    
    def launch_roomtype(self,b):
        with self.out:
            self.hideHotelAggregatesDashboard()
            # %run Local_Aggregates/RoomType.ipynb
            run(self.user, self.host, self.out)

    
    def launch_leastguests(self,b):
        with self.out:
            self.hideHotelAggregatesDashboard()
            # %run Local_Aggregates/LeastGuests.ipynb
            run(self.user, self.host, self.out)

    def hideHotelAggregatesDashboard(self):
        self.handicaproom.close()
        self.leastreserve.close()
        self.mostcreditcard.close()
        self.highestpaid.close()
        self.mostdiscount.close()
        self.roomtype.close()
        self.leastguests.close()

def run(user, host, output):
    x = HotelAggregatesDashboard(user, host, output)
    x.displayHotelAggregatesDashboard()
